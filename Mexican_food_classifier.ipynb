# %% [markdown]
# # Mexican Food Classifier
#
# ![alt text](http://ichef.bbci.co.uk/news/999/cpsprodpb/131C3/production/_94257287_thinkstockphotos-491169768.jpg)
#
# This project idea came to my mind because it can help to the tourism sector in Mazatlán, Mexico. What if we build an app that can detect the most popular mexican dishes, just by taking a picture when we are getting food in a restaurant. Tourists can take pictures of the food they are getting and identify what are them and even get a recipe!
#
# There are already some projects implementing the same idea, using the FOOD-101 dataset, which contains more classes. You can read a paper implementing the same idea here: https://arxiv.org/ftp/arxiv/papers/1612/1612.00983.pdf
#
# By doing these, we are promoting the food made in Mexico and helping the tourism sector by bringing more  interested people to visit our beautiful town!
#
# I'll train this image classifier to recognize 9 different mexican food dishes given an image.This can be implemented in a phone app that tells you the type of food your camera is looking at.
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content

# %% [markdown]
# # Working on a "Mexican Food Dataset"

# %% [markdown]
# I used the Google Images Download library.  A Python Script for 'searching' and 'downloading' hundreds of Google images to the local hard disk!. You can use this library with the following instruction:
#
# pip install google_images_download #Installing the package
#
# from google_images_download import google_images_download   #importing the library
#
# response = google_images_download.googleimagesdownload()   #class instantiation
#
# arguments = {"keywords":"Polar bears,baloons,Beaches","limit":20,"print_urls":True}   #creating list of arguments
# paths = response.download(arguments)   #passing the arguments to the function
# print(paths)   #printing absolute paths of the downloaded images
#
# I collected images using this library and uploaded a food dataset to Google Drive.
#
# This app will identify 9 different kind of mexican food dishes:
#
# - Aguachile
# - Callos de Hacha
# - Ceviche de Camarón
# - Ceviche de Sierra
# - Chilaquiles
# - Coctel de Camarón
# - Tacos Gobernador
# - Pozole
# - Pescado Zarandeado

# %% [markdown]
# Many Americans associate Mexican cuisine exclusively with tacos, enchiladas, refried beans and tequila. However, fish is also prominent in Mexican cooking, especially along the Pacific coast. In fact, the region near Mazatlan has long been recognized as an ideal spot for fishing for both food and sport.
#
# **Aguachile**
#
# ![alt text](https://cdn.kiwilimon.com/recetaimagen/28638/th5-640x426-28924.jpg)
#
# If you love ceviche, then Mexico's Shrimp Aguachile is for you. Traditionally made with raw shrimp, lime juice, chilies, cucumber, and onion, it's served immediately while still totally raw, unlike most other ceviche recipes. This dish is very popular in  Sinaloa, México, and it's unbelievably delicious given its simplicity.
#
# **Callos de Hacha**
#
# ![alt text](https://media-cdn.tripadvisor.com/media/photo-s/07/bc/af/dd/la-unica.jpg)
#
# Callos de Hacha or scallops is a typical dish of the Pacific coast of Mexico. This delicious dish is very popular in places like Sinaloa, Nayarit, Sonora and Baja California. Some call it a "delicacy of raw seafood lovers". Many also say it’s a great way to get rid of a hangover after a big celebration. The main ingredients are scallops, fresh or dried chilies, lemon and water. There are also versions in which fresh vegetables are added. I hope you enjoy this delicious Mexican dish.
#
# **Ceviche de Camarón**
#
# ![alt text](http://3.bp.blogspot.com/-BB3BRzokZcw/VAaI_KBSBZI/AAAAAAAAAgc/678dNCx9cko/s1600/ceviche_camaron.jpg)
#
#
# Shrimp Ceviche is very popular in the Pacific coast region, especifically, Mazatlán. Ceviche features raw fish and seafood marinated and cured in citrus juices like lemon or lime. This process “cooks” the fish much like preparing it with heat, giving it a firm texture. Other ingredients include fresh cucumbers, tomatoes, celery, onions and corn, seasoned with cilantro, chile or other bold spices. This tasty dish is both filling and pleasing to the palate.
#
# **Ceviche de Sierra**
#
# ![alt text](https://mazatleco.com/wp-content/uploads/2014/08/Ceviche-de-sierra-mazatleco.jpg)
#
# This ceviche is typical of Mazatlan, Sinaloa Mexico. It's called Ceviche de Sierra over there; Sierra is just another name for Spanish Mackerel. We prepare this fish by cooking it with the acidity of lime juice. Perfect for hot days!
#
# **Chilaquiles**
#
# ![alt text](https://www.cocinavital.mx/wp-content/uploads/2017/11/chilaquiles-rojos-paso-a-paso.jpg)
#
# Chilaquiles are a breakfast staple in Mexico. There are red chilaquiles and green chilaquiles, depending on the type of salsa that you decide to make. Chilaquiles start with a bed of freshly made corn tortilla chips, which can be either baked or fried.
#
# **Coctel de Camarón**
#
# ![alt text](https://cocina-casera.com/mx/wp-content/uploads/2017/11/campechana.jpg)
#
# Coctel de camarones, or Mexican shrimp cocktail. I love this version of shrimp cocktail, it’s sort of like a virgin Bloody Mary with cucumber, celery, red onions, avocados and lots of shrimp. Perfect for dipping, or eating with a spoon. Or picking out the shrimp pieces with a fork, then the avocado pieces, and then eating the rest with a spoon as if it were gazpacho.
#
# **Tacos Gobernador**
#
# ![alt text](https://www.cocinavital.mx/wp-content/uploads/2017/08/tacos-gobernador.jpg)
#
# These Tacos Gobernador are the perfect crispy cheesy shrimp tacos you will ever come across. These Tacos Gobernador translates to Governor’s Tacos and they are just hyper-delicious. These are cheesy shrimp tacos folded in between a crispy corn tortilla with all the toppings. I promise these tacos will just make you happy every time you make them. Poblano peppers strips, thinly sliced onions, juicy sweet tomatoes, serrano pepper and garlic cooked with shrimps and then laid on top of deliciously melted cheese in between a corn tortilla that is perfectly pan fried in butter. Oh!  And the serrano pepper offers the perfect hint of spiciness you will love.
#
# **Pozole**
#
# ![alt text](https://obson.files.wordpress.com/2013/02/receta-pozole.jpg)
#
# Pozole, which means "hominy", is a traditional soup or stew from Mexico. It is made from hominy, with meat, and can be seasoned and garnished with shredded cabbage, chile peppers, onion, garlic, radishes, avocado, salsa or limes. Pozole is typically served on New Year's Eve to celebrate the new year.
#
# **Pescado Zarandeado**
#
# ![alt text](https://www.diariohispaniola.com/fotos/1/Pescado-a-la-Talla-Acapulco.jpg)
#
# Mexican Style Grilled Fish (Zarandeado) is a  whole fish, marinated with lime & chilies then grilled over charcoal. It's very popular in Sinaloa.

# %% [markdown]
# # Importing the libraries
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# We need pillow version of 5.3.0
# We will uninstall the older version first
# !pip uninstall -y Pillow
# Install the new one
# !pip install Pillow==5.3.0
# Let's verify the version
# This should print 5.3.0. If it doesn't, then restart your runtime:
# Menu > Runtime > Restart Runtime
# !pip install image
# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.4.0-cp36-cp36m-linux_x86_64.whl
# !pip3 install torchvision
import PIL
print(PIL.PILLOW_VERSION)
# Out:
# Uninstalling Pillow-5.3.0:
#   Successfully uninstalled Pillow-5.3.0
# Collecting Pillow==5.3.0
#   Using cached https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl
# Installing collected packages: Pillow
# Successfully installed Pillow-5.3.0
# Requirement already satisfied: image in /usr/local/lib/python3.6/dist-packages (1.5.27)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from image) (5.3.0)
# Requirement already satisfied: django in /usr/local/lib/python3.6/dist-packages (from image) (2.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from django->image) (2018.7)
# Requirement already satisfied: torch==0.4.0 from http://download.pytorch.org/whl/cu80/torch-0.4.0-cp36-cp36m-linux_x86_64.whl in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.2.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchvision) (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (5.3.0)
# 5.3.0

# %%
# We will verify that GPU is enabled for this notebook
# Following should print: CUDA is available!  Training on GPU ...
# if it prints otherwise, then you need to enable GPU: 
# From Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch
import time
import numpy as np
from torch import nn, optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision
from collections import OrderedDict
from torch.autograd import Variable
from PIL import Image
from torch.optim import lr_scheduler
import copy
import json
import os
import warnings
from os.path import exists
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# CUDA is available!  Training on GPU ...
# cuda:0

# %% [markdown]
# # Load the data
#
# Here you'll use 'torchvision'  to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The dataset is split into two parts, training and validation. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. If you use a pre-trained network, you'll also need to make sure the input data is resized to 224x224 pixels as required by the networks.
#
# The validation set is used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks available from 'torchvision' were trained on the ImageNet dataset where each color channel was normalized separately. For both sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's ' [0.485, 0.456, 0.406]'  and for the standard deviations ''[0.229, 0.224, 0.225]' , calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
# Download the dataset and unzip de folder
#!gdown https://drive.google.com/uc?id=1xsP_yv__XejYS_tKIhkV-WPQS_quJ6Vx
# !unzip mexican_food.zip
# Out:
# Archive:  mexican_food.zip
#    creating: mexican_food/
#    creating: mexican_food/train/
#    creating: mexican_food/train/aguachile/
#   inflating: mexican_food/train/aguachile/1. camarones-en-aguachile-3-2.jpg
#  extracting: mexican_food/train/aguachile/10. cebf8aa3-6e0b-4b7d-a9e0-4d80a9e17e94.jpg
#  extracting: mexican_food/train/aguachile/11. maxresdefault.jpg
#   inflating: mexican_food/train/aguachile/12. jpk7inrlksxzhvzpdz7a_image.jpg
#   inflating: mexican_food/train/aguachile/13. 20140908-aguachile-in-mexico-daniel-gritzer-2.jpg
#   inflating: mexican_food/train/aguachile/14. aguachile-de-camaro%cc%81n-1.jpg
#   inflating: mexican_food/train/aguachile/15. ac23696e6db8537b9d5a9457f6f3cfea.jpg
#   inflating: mexican_food/train/aguachile/17. 20140908-aguachile-vicky-wasik-30-1500x1125.jpg
#   inflating: mexican_food/train/aguachile/18. 9c7974d25b4440d4b5b0c7097ae893ce.jpg
#   inflating: mexican_food/train/aguachile/2. image_url=https%3a%2f%2fcdn-image.foodandwine.com%2fsites%2fdefault%2ffiles%2fstyles%2fmedium_2x%2fpublic%2f201305-xl-scallop-ceviche-with-aguachile.jpg%3fitok%3drocrd6i6&w=1000&c=sc&poi=face&q=70.jpg
#   inflating: mexican_food/train/aguachile/21. aguachile_close_up_tejado-1.jpg
#   inflating: mexican_food/train/aguachile/22. 500xnxscallopaguachile.jpg
#   inflating: mexican_food/train/aguachile/25. aguachile.jpg
#   inflating: mexican_food/train/aguachile/26. aguachili4-600x381.jpg
#  extracting: mexican_food/train/aguachile/27. def072c0-9ba3-4fd5-9747-5616dbcdab36.jpg
#   inflating: mexican_food/train/aguachile/28. th5-640x426-21988.jpg
#   inflating: mexican_food/train/aguachile/3. 1516665712shrimp-aguachile-large.jpg
#   inflating: mexican_food/train/aguachile/30. aguachile-negro-2.jpg
#   inflating: mexican_food/train/aguachile/31. shrimp-and-scallop-aguachile-rojo-e1526328877177.jpg
#  extracting: mexican_food/train/aguachile/32. aguachile1.jpg
#   inflating: mexican_food/train/aguachile/34. img_camarones_en_aguachile_rojo_67325_600.jpg
#   inflating: mexican_food/train/aguachile/35. d1d17bff-5502-437c-a4c3-a7b62f30bce8.jpg
#   inflating: mexican_food/train/aguachile/36. avocado-aguachiles-1-690x292.jpg
#   inflating: mexican_food/train/aguachile/38. lime_chili_shrimp_masterchefu-800x521.jpg
#   inflating: mexican_food/train/aguachile/39. shrimpaguachiletostaditas-1.jpg
#   inflating: mexican_food/train/aguachile/4. plated2.jpg
#   inflating: mexican_food/train/aguachile/41. mexican-aguachile.jpg
#   inflating: mexican_food/train/aguachile/42. 20140908-aguachile-vicky-wasik-20-1500x1125.jpg
#   inflating: mexican_food/train/aguachile/43. 65.jpg
#   inflating: mexican_food/train/aguachile/48. aguachile-vegano-4.jpg
#   inflating: mexican_food/train/aguachile/51. web-article-enrique-olvera-charred-octopus-habenero-avocado-cilantro-salad-cosme-nyc-summer-entertaining-recipe.jpg
#   inflating: mexican_food/train/aguachile/52. hqdefault.jpg
#   inflating: mexican_food/train/aguachile/53. ensalada-aguachile-with-california-avocado_maxsidesize=800.jpg
#   inflating: mexican_food/train/aguachile/54. fountaine-sylvia-augachili-111.jpg
#   inflating: mexican_food/train/aguachile/55. aguachiles.jpg
#   inflating: mexican_food/train/aguachile/56. image-1-e1485569458651.jpeg
#   inflating: mexican_food/train/aguachile/57. aguachili3-300x194.jpg
#   inflating: mexican_food/train/aguachile/58. scallop-aguachile-600x450.jpg
#   inflating: mexican_food/train/aguachile/59. tostada-de-aguachile.jpg
#   inflating: mexican_food/train/aguachile/61. maxresdefault.jpg
#   inflating: mexican_food/train/aguachile/62. 2c443513187dd9c1e0ed8c11166f0755.jpg
#   inflating: mexican_food/train/aguachile/65. camaromes_raw1.jpg
#  extracting: mexican_food/train/aguachile/7. th5-640x426-32325.jpg
#  extracting: mexican_food/train/aguachile/70. aguachile_vegano.jpg
#   inflating: mexican_food/train/aguachile/71. aguachile-sinaloense.jpg
#   inflating: mexican_food/train/aguachile/72. ls.jpg
#   inflating: mexican_food/train/aguachile/73. la-1519847047-hxw4ktgzlv-snap-image.jpg
#   inflating: mexican_food/train/aguachile/78. img_camarones_al_aguachile_paso_a_paso_35376_orig.jpg
#   inflating: mexican_food/train/aguachile/8. aguachile-final-1.jpg
#   inflating: mexican_food/train/aguachile/80. aguachile-01--820x410-c.jpg
#   inflating: mexican_food/train/aguachile/81. aguachile.jpg
#   inflating: mexican_food/train/aguachile/82. 040.jpg
#   inflating: mexican_food/train/aguachile/84. 68247303f96bb3ab5e2a50db48c69dd4.jpg
#   inflating: mexican_food/train/aguachile/85. img_0058.jpg
#   inflating: mexican_food/train/aguachile/86. maxresdefault.jpg
#   inflating: mexican_food/train/aguachile/88. th5-640x426-12081.jpg
#   inflating: mexican_food/train/aguachile/89. r_1350_1475613268.jpg
#   inflating: mexican_food/train/aguachile/90. img_1454.jpg
#   inflating: mexican_food/train/aguachile/92. 1244800.jpg
#  extracting: mexican_food/train/aguachile/93. aguachile_close_up_el_faro-1.jpg
#   inflating: mexican_food/train/aguachile/94. img_8065.jpg
#  extracting: mexican_food/train/aguachile/95. r_618_1475614513.jpg
#   inflating: mexican_food/train/aguachile/96. 20090615+024.jpg
#   inflating: mexican_food/train/aguachile/97. shrimp-aguachile.jpg
#   inflating: mexican_food/train/aguachile/99. aguachile-guachinango-web.jpg
#    creating: mexican_food/train/callos_hacha/
#   inflating: mexican_food/train/callos_hacha/1. aguachile-de-callo-de-hacha.jpg
#  extracting: mexican_food/train/callos_hacha/10. maxresdefault.jpg
#   inflating: mexican_food/train/callos_hacha/11. barracruda-s.jpg
#   inflating: mexican_food/train/callos_hacha/12. 500xnxscallopaguachile.jpg
#   inflating: mexican_food/train/callos_hacha/13. arabuko_frank_salmon_callodehacha_002.jpg
#   inflating: mexican_food/train/callos_hacha/14. o.jpg
#   inflating: mexican_food/train/callos_hacha/15. dsc_0036a-600x600.jpg
#   inflating: mexican_food/train/callos_hacha/16. callos.jpg
#  extracting: mexican_food/train/callos_hacha/18. callo-de-hacha-con-tocino-2.jpg
#   inflating: mexican_food/train/callos_hacha/19. 405_61192831.jpg
#   inflating: mexican_food/train/callos_hacha/2. callo_de_hacha_mariscos_el_rey.jpg
#   inflating: mexican_food/train/callos_hacha/20. callodehachajap3-450x450.jpg
#   inflating: mexican_food/train/callos_hacha/21. 9029dbf1d4e4be20a917844d3906cfee.jpg
#   inflating: mexican_food/train/callos_hacha/22. callos-de-hacha-a-la-parrilla_recetas_chef-oropeza-jpg.jpg
#   inflating: mexican_food/train/callos_hacha/24. callo.jpg
#   inflating: mexican_food/train/callos_hacha/25. callo-de-hacha.jpg
#   inflating: mexican_food/train/callos_hacha/26. hqdefault.jpg
#   inflating: mexican_food/train/callos_hacha/27. image_url=https%3a%2f%2fpespdotcom.files.wordpress.com%2f2018%2f10%2ffc8e85be-4d48-4614-ab56-65848c5904b0.jpg%3fw%3d250&w=1000&c=sc&poi=face&q=70.jpg
#   inflating: mexican_food/train/callos_hacha/28. aguachile.jpg
#   inflating: mexican_food/train/callos_hacha/29. agosto-07-callo.jpg
#   inflating: mexican_food/train/callos_hacha/3. r_3257_1475609995.jpg
#   inflating: mexican_food/train/callos_hacha/31. callos-hacha-ajo.jpg
#   inflating: mexican_food/train/callos_hacha/32. callo-de-hacha.jpg
#   inflating: mexican_food/train/callos_hacha/33. callos-de-hacha-sellados-con-vinagreta-de-mango.jpg
#   inflating: mexican_food/train/callos_hacha/34. callos-de-hacha.jpg
#   inflating: mexican_food/train/callos_hacha/35. callo-de-hacha-a-los.jpg
#   inflating: mexican_food/train/callos_hacha/36. th5-640x426-1893.jpg
#   inflating: mexican_food/train/callos_hacha/37. 1478582-n.jpg
#   inflating: mexican_food/train/callos_hacha/39. callo-de-hacha.jpg
#   inflating: mexican_food/train/callos_hacha/4. esparragos-con-callo-de-hacha-y-prosciutto-613x342.jpg
#   inflating: mexican_food/train/callos_hacha/41. callo-de-hacha-en-aguachile.jpg
#   inflating: mexican_food/train/callos_hacha/45. callos-de-hacha-mazatlan.jpg
#   inflating: mexican_food/train/callos_hacha/5. callo-de-hacha-redondo-e1469906300102.jpeg
#   inflating: mexican_food/train/callos_hacha/50. o.jpg
#   inflating: mexican_food/train/callos_hacha/53. la-unica.jpg
#   inflating: mexican_food/train/callos_hacha/58. callo-de-hacha.jpg
#   inflating: mexican_food/train/callos_hacha/6. callo-de-hacha-aguachile.jpg
#   inflating: mexican_food/train/callos_hacha/61. aguachile-de-callo-de-hacha.jpg
#   inflating: mexican_food/train/callos_hacha/63. 29080649672_05f90eaf8c_b.jpg
#   inflating: mexican_food/train/callos_hacha/68. stanleys-bar-grill.jpg
#   inflating: mexican_food/train/callos_hacha/69. bfa37f58cb45eeb7995aa47e6f50a624.jpg
#   inflating: mexican_food/train/callos_hacha/7. callo-de-hacha-con-perejil-y-c%c3%adtricos_reynolds-1024x341.jpg
#   inflating: mexican_food/train/callos_hacha/70. callo-de-hacha-e1537988275493.jpg
#   inflating: mexican_food/train/callos_hacha/74. callo-de-hacha-at-xochi.-photo-by-paula-murphy..jpeg
#   inflating: mexican_food/train/callos_hacha/78. callos-de-hacha-a-la-parrilla_recetas_chef-oropeza-jpg-400x450..jpg
#   inflating: mexican_food/train/callos_hacha/79. al9i0290-copy.jpg
#   inflating: mexican_food/train/callos_hacha/8. e2b06dd6-526f-4e49-9ad3-b1a15eb41877.jpg
#  extracting: mexican_food/train/callos_hacha/84. callo_cristalazo.0.jpg
#   inflating: mexican_food/train/callos_hacha/85. callo-de-hacha-fresco.jpg
#   inflating: mexican_food/train/callos_hacha/88. 30e0056d-99b4-4f6d-82d3-63e1ecb88d4a.jpg
#   inflating: mexican_food/train/callos_hacha/89. thumb400x300-7152.jpg
#   inflating: mexican_food/train/callos_hacha/9. photo.jpg
#   inflating: mexican_food/train/callos_hacha/94. callo-de-hacha-laminado.jpg
#   inflating: mexican_food/train/callos_hacha/95. 0d7b43ec7ea50ce9d55eb54fc9fb0197.jpg
#   inflating: mexican_food/train/callos_hacha/97. hqdefault.jpg
#   inflating: mexican_food/train/callos_hacha/98. callos-de-hacha-para.jpg
#    creating: mexican_food/train/ceviche_camaron/
#   inflating: mexican_food/train/ceviche_camaron/1. img_6458.jpg
#   inflating: mexican_food/train/ceviche_camaron/10. shrimp-ceviche-ceviche-de-camaron-recipe-main-photo.jpg
#  extracting: mexican_food/train/ceviche_camaron/11. c3039468-71fb-49bc-b886-822c67cf7c51.jpg
#   inflating: mexican_food/train/ceviche_camaron/12. 80.jpg
#   inflating: mexican_food/train/ceviche_camaron/13. img_ceviche_de_camaron_mexicano_33881_600.jpg
#   inflating: mexican_food/train/ceviche_camaron/14. photo.jpg
#   inflating: mexican_food/train/ceviche_camaron/15. img_6518_5145.jpg
#   inflating: mexican_food/train/ceviche_camaron/16. dd64406c-cfc5-4b84-b84b-0e052f00e9fe.jpg
#   inflating: mexican_food/train/ceviche_camaron/17. f30d28cd-b158-4c48-840e-9d90cebea781.jpg
#   inflating: mexican_food/train/ceviche_camaron/18. ceviche-de-gambas.jpg
#  extracting: mexican_food/train/ceviche_camaron/19. th5-640x426-23266.jpg
#   inflating: mexican_food/train/ceviche_camaron/2. ceviche-de-camaron.jpg
#   inflating: mexican_food/train/ceviche_camaron/20. ceviche-de-camar%c3%b3n-ecuatoriano.jpg
#   inflating: mexican_food/train/ceviche_camaron/21. ceviche_de_camarones.jpg
#   inflating: mexican_food/train/ceviche_camaron/22. maxresdefault.jpg
#   inflating: mexican_food/train/ceviche_camaron/23. tostadas-de-ceviche-de-camaron.jpg
#   inflating: mexican_food/train/ceviche_camaron/24. gourmet%20nota%20ceviche_0.jpg
#   inflating: mexican_food/train/ceviche_camaron/27. p1020483.jpg
#   inflating: mexican_food/train/ceviche_camaron/3. ceviche-de-camarones-y-aguacate.jpg
#   inflating: mexican_food/train/ceviche_camaron/30. coconut-and-shrimp-ceviche.jpg
#   inflating: mexican_food/train/ceviche_camaron/31. 022433db-b5fd-44bf-ae2e-874b01656eb6.jpg
#   inflating: mexican_food/train/ceviche_camaron/32. 156456_800x600_crop_55c3a43641f3d.jpg
#   inflating: mexican_food/train/ceviche_camaron/33. ffee2447b152494b43d9816faaea83c8_xl.jpg
#   inflating: mexican_food/train/ceviche_camaron/34. ceviche-de-camaron-web.jpg
#   inflating: mexican_food/train/ceviche_camaron/35. ceviche-de-camar%c3%b3n-y-tomate.jpg
#   inflating: mexican_food/train/ceviche_camaron/36. shrimp-ceviche-ck-226783-x.jpg
#   inflating: mexican_food/train/ceviche_camaron/37. dfc6cf4b59e1a493fc79cef0fa221056--snap-food-hamilton-beach.jpg
#   inflating: mexican_food/train/ceviche_camaron/38. cebiche-camaron-tu-cebiche-600x401.jpg
#   inflating: mexican_food/train/ceviche_camaron/39. photo.jpg
#   inflating: mexican_food/train/ceviche_camaron/4. 4f982501-425c-4723-8628-a8b30936f82c.jpg
#   inflating: mexican_food/train/ceviche_camaron/40. pic-_145-ceviche-de-camaron-palmito-y-aguacate-final-low.jpg
#   inflating: mexican_food/train/ceviche_camaron/46. 0ad9658f-b7be-4ea6-a481-d7654366344c.jpg
#   inflating: mexican_food/train/ceviche_camaron/48. maxresdefault.jpg
#   inflating: mexican_food/train/ceviche_camaron/49. ceviche_de_camaron_y_mango.jpg
#   inflating: mexican_food/train/ceviche_camaron/5. img_ceviche_de_camarones_15460_600.jpg
#   inflating: mexican_food/train/ceviche_camaron/50. ceviche-camaron-jaiba.jpg
#   inflating: mexican_food/train/ceviche_camaron/51. cevichecamaron-1522692692-a86091f9164b94a8c8752bc3940d91f5.jpg
#   inflating: mexican_food/train/ceviche_camaron/52. ceviche-camarones-1.jpg
#   inflating: mexican_food/train/ceviche_camaron/53. shrimp-ceviche-with-avocado.jpg
#   inflating: mexican_food/train/ceviche_camaron/55. shrimp-ceviche1.jpg
#   inflating: mexican_food/train/ceviche_camaron/56. ceviche_camaron.jpg
#   inflating: mexican_food/train/ceviche_camaron/57. ceviche-camarones.jpg
#   inflating: mexican_food/train/ceviche_camaron/59. ceviche-camaron-sinaloa.jpg
#   inflating: mexican_food/train/ceviche_camaron/6. shrimp-ceviche-ceviche-de-camaron.jpg
#   inflating: mexican_food/train/ceviche_camaron/60. ceviche-camarones-3.jpg
#   inflating: mexican_food/train/ceviche_camaron/61. 9120818-camaron-shrimp-ceviche-raw-seafood-salad-mexico-chili-sauces.jpg
#   inflating: mexican_food/train/ceviche_camaron/65. ceviche-camaron-coctel-tomate-700x400.jpg
#   inflating: mexican_food/train/ceviche_camaron/66. ceviche-de-camaron.jpg
#   inflating: mexican_food/train/ceviche_camaron/68. 04110-preparar-ceviche-camarones-mango-verde.jpg
#   inflating: mexican_food/train/ceviche_camaron/69. 140243lrg.jpg
#   inflating: mexican_food/train/ceviche_camaron/7. ceviche-de-camaron-estilo-nayarit.jpg
#   inflating: mexican_food/train/ceviche_camaron/71. photo.jpg
#   inflating: mexican_food/train/ceviche_camaron/72. ceviche_camaron1-300x199.jpg
#   inflating: mexican_food/train/ceviche_camaron/73. cevichecamarones.jpg
#   inflating: mexican_food/train/ceviche_camaron/74. ceviche_de_camaron_y_palta_64427_600.jpg
#   inflating: mexican_food/train/ceviche_camaron/78. ceviche-camaron-mango.jpg
#   inflating: mexican_food/train/ceviche_camaron/79. ceviche-de-camaron.jpg
#  extracting: mexican_food/train/ceviche_camaron/8. 1-ecuadorian-shrimp-ceviche-recipe.jpg
#   inflating: mexican_food/train/ceviche_camaron/80. img_7514.jpg
#   inflating: mexican_food/train/ceviche_camaron/82. shrimpcheviche_170_3200x24000-v1-copy.jpg
#   inflating: mexican_food/train/ceviche_camaron/83. shrimp-and-crab-ceviche-11.jpg
#   inflating: mexican_food/train/ceviche_camaron/84. destacada-ceviche-400x200.jpg
#   inflating: mexican_food/train/ceviche_camaron/85. ceviche-camarones-2.jpg
#   inflating: mexican_food/train/ceviche_camaron/89. ceviche-camarones-d1257775f0d86f24206fa4f8c4e53854.jpg
#   inflating: mexican_food/train/ceviche_camaron/9. 63725_640x428.jpg
#   inflating: mexican_food/train/ceviche_camaron/90. o.jpg
#   inflating: mexican_food/train/ceviche_camaron/92. ceviche-de-camaron.jpg
#   inflating: mexican_food/train/ceviche_camaron/93. litro_ceviche_de_camaron_mariscos_el_rey.jpg
#   inflating: mexican_food/train/ceviche_camaron/94. ceviche-de-camaron-mexicano.jpg
#    creating: mexican_food/train/ceviche_sierra/
#   inflating: mexican_food/train/ceviche_sierra/1. th5-640x426-2259.jpg
#   inflating: mexican_food/train/ceviche_sierra/10. ceviche-sierra-300x225.jpg
#  extracting: mexican_food/train/ceviche_sierra/12. 9246511050_90b71109f3_b.jpg
#   inflating: mexican_food/train/ceviche_sierra/14. 30739707_711822155875455_7712178094158208702_n-223591.jpg
#  extracting: mexican_food/train/ceviche_sierra/15. inicio%2bvideo%2bhd.jpg
#   inflating: mexican_food/train/ceviche_sierra/16. photo.jpg
#   inflating: mexican_food/train/ceviche_sierra/18. 7e28a8e4dd91fc7abfed0c7ee7c152ea.jpg
#   inflating: mexican_food/train/ceviche_sierra/19. 30079318_420549371739518_5902674301940662272_n.jpg
#  extracting: mexican_food/train/ceviche_sierra/2. fnsv8ecik7c7zf2.large.jpg
#   inflating: mexican_food/train/ceviche_sierra/20. main-1.jpg
#   inflating: mexican_food/train/ceviche_sierra/21. bvcyl0ycqaec5qk.jpg
#   inflating: mexican_food/train/ceviche_sierra/23. ceviche-playero.jpg
#   inflating: mexican_food/train/ceviche_sierra/24. 2010mexico-047.jpg
#   inflating: mexican_food/train/ceviche_sierra/26. 5e3c1e04a8335564523a7396338007f9.jpg
#   inflating: mexican_food/train/ceviche_sierra/3. csb_5626_xcopiarx.jpg
#   inflating: mexican_food/train/ceviche_sierra/31. cevicheconzanahoria.jpg
#   inflating: mexican_food/train/ceviche_sierra/32. maxresdefault.jpg
#  extracting: mexican_food/train/ceviche_sierra/35. sdc17546.jpg
#   inflating: mexican_food/train/ceviche_sierra/4. fszsm8rik7c7zlk.rectangle1.jpg
#   inflating: mexican_food/train/ceviche_sierra/49. ceviches_mariscos_danny.jpg
#   inflating: mexican_food/train/ceviche_sierra/5. maxresdefault.jpg
#  extracting: mexican_food/train/ceviche_sierra/55. 8480705112_7f65a66ac0_z.jpg
#  extracting: mexican_food/train/ceviche_sierra/6. 240190221_2476b7ae74_z.jpg
#   inflating: mexican_food/train/ceviche_sierra/7. ceviche-sierra.jpg
#   inflating: mexican_food/train/ceviche_sierra/70. 36722299_1848100962166181_3064064488266268672_n.jpg
#   inflating: mexican_food/train/ceviche_sierra/71. o.jpg
#   inflating: mexican_food/train/ceviche_sierra/8. 359-378.jpg
#  extracting: mexican_food/train/ceviche_sierra/89. cbxlzmnumaaqddd.jpg
#   inflating: mexican_food/train/ceviche_sierra/9. portadas-joy-3.jpg
#    creating: mexican_food/train/chilaquiles/
#   inflating: mexican_food/train/chilaquiles/1. chilaquiles_rojos.jpg
#   inflating: mexican_food/train/chilaquiles/12. 0406_edf_chilaquiles_horiz.jpg
#   inflating: mexican_food/train/chilaquiles/13. 1280px-01_chilaquiles_verdes_con_frijoles_chinos-57c4a4f73df78cc16ec9eb54.jpg
#   inflating: mexican_food/train/chilaquiles/14. how-to-make-chilaquiles-recipe.jpg
#   inflating: mexican_food/train/chilaquiles/15. chilaquiles-verdes-horiz-b-1600.jpg
#   inflating: mexican_food/train/chilaquiles/16. 6b5a1043-0cd0-4056-8e40-ea7a02de1f4c.jpg
#   inflating: mexican_food/train/chilaquiles/18. chilaquiles-egg-bake-102846836_horiz.jpg
#   inflating: mexican_food/train/chilaquiles/19. b645688a-9254-42ee-b9fd-5565cef23e69.jpg
#   inflating: mexican_food/train/chilaquiles/2. 354951_hires.jpg
#   inflating: mexican_food/train/chilaquiles/20. chipotle-chicken-chilaquiles.jpeg
#   inflating: mexican_food/train/chilaquiles/22. chilaquiles-rojos-recipe_0.jpg
#  extracting: mexican_food/train/chilaquiles/24. chilaquiles-with-fried-eggs.jpg
#   inflating: mexican_food/train/chilaquiles/26. 1351625210016.jpeg
#   inflating: mexican_food/train/chilaquiles/27. chilaquiles-rojos-on-a-white-plate.jpg
#   inflating: mexican_food/train/chilaquiles/28. chilaquiles-verdes-in-skilet-6.jpg
#   inflating: mexican_food/train/chilaquiles/29. sfs_chilaquiles-13.jpg
#  extracting: mexican_food/train/chilaquiles/3. atk-chilaquiles-lede02.jpg
#   inflating: mexican_food/train/chilaquiles/31. red-chicken-chilaquiles-recipe-28-600x600.jpg
#   inflating: mexican_food/train/chilaquiles/32. 01ccace3-ffe7-4625-8cde-fcdb983264b0.jpg
#   inflating: mexican_food/train/chilaquiles/33. chilaquiles-with-salsa-verde-900x570-srgb.jpg
#   inflating: mexican_food/train/chilaquiles/35. th5-640x426-9713.jpg
#   inflating: mexican_food/train/chilaquiles/36. easy-skillet-chicken-chilaquiles-01.jpg
#   inflating: mexican_food/train/chilaquiles/37. mar-3-chilaquiles-with-poached-eggs-652x869.jpg
#  extracting: mexican_food/train/chilaquiles/38. easy-red-chilaquiles-small-1.jpg
#   inflating: mexican_food/train/chilaquiles/39. chilaquiles_manifesto_chilaquiles-rojos_yes-more-please.jpg
#   inflating: mexican_food/train/chilaquiles/4. chilaquiles-with-salsa-verde-2a.jpg
#   inflating: mexican_food/train/chilaquiles/40. w-rbs0rh9nzr87dhaws51rcijmxz--hoz6dyafek1fh0s_a8etndttowgzipkoaunh5awt7mhxdsetf3b7gy37znixhkzmk2veqz0qa=w600-l68.jpg
#  extracting: mexican_food/train/chilaquiles/41. chilaquiles-rojos-hero.jpg
#   inflating: mexican_food/train/chilaquiles/42. chilaquiles-rojos-.jpg
#   inflating: mexican_food/train/chilaquiles/43. chilaquiles-recipe-vert-2016-11-21-3.jpg
#   inflating: mexican_food/train/chilaquiles/44. chicken-chilaquiles-recipe.jpg
#   inflating: mexican_food/train/chilaquiles/46. taqueria_habanero_dc_chilaquiles.0.0.jpg
#   inflating: mexican_food/train/chilaquiles/47. chilaquiles-for-web-930x550.jpg
#   inflating: mexican_food/train/chilaquiles/48. tex-mex-chilaquiles-1-5.jpg
#   inflating: mexican_food/train/chilaquiles/5. eggshop-chilaquiles-recipe-hc-030618.jpg
#   inflating: mexican_food/train/chilaquiles/50. 03recipehealth_600-articlelarge.jpg
#   inflating: mexican_food/train/chilaquiles/51. chilaquiles-crema-verde-con-pollo.jpg
#   inflating: mexican_food/train/chilaquiles/52. chilaquiles-rojos-1-1.jpg
#   inflating: mexican_food/train/chilaquiles/53. chillaquilles-i-howsweeteats.com-2.jpg
#   inflating: mexican_food/train/chilaquiles/54. 4f2b0799-0b85-4089-b7c8-e2407c15bd2c.jpg
#   inflating: mexican_food/train/chilaquiles/55. green-chilaquiles-chilaquiles-verde.jpg
#   inflating: mexican_food/train/chilaquiles/56. mexican-chilaquiles-rojos-550.jpg
#   inflating: mexican_food/train/chilaquiles/59. 11-n7adj3j7ak7h2d7jfbhzd2aqi0wuub5sepyre6uj1g.jpg
#   inflating: mexican_food/train/chilaquiles/6. chilaquiles-verdes-recipe-with-baked-tortilla-chips.jpg
#   inflating: mexican_food/train/chilaquiles/63. 640x478_ac.jpg
#   inflating: mexican_food/train/chilaquiles/64. maxresdefault.jpg
#   inflating: mexican_food/train/chilaquiles/65. chilaquiles2bw-f.jpg
#   inflating: mexican_food/train/chilaquiles/66. chilaquiles-2-1024x700-480x270.jpg
#   inflating: mexican_food/train/chilaquiles/68. chilaquiles.jpg
#   inflating: mexican_food/train/chilaquiles/69. mexican-chilaquiles-rojos-6.jpg
#   inflating: mexican_food/train/chilaquiles/7. 16308.jpg
#   inflating: mexican_food/train/chilaquiles/71. amazing-vegan-chilaquiles-with-diy-baked-chips-5-ingredient-chipotle-sauce-and-scrambled-tofu-vegan-glutenfree1.jpg
#   inflating: mexican_food/train/chilaquiles/73. 7065e3ab-b7f4-4bf4-9eb0-8ee4463781de.jpg
#   inflating: mexican_food/train/chilaquiles/74. im0-630x480.jpg
#   inflating: mexican_food/train/chilaquiles/75. chilaquiles-with-salsa-verde-3a.jpg
#   inflating: mexican_food/train/chilaquiles/79. breakfast-737876157-5b609960c9e77c002512e6be.jpg
#   inflating: mexican_food/train/chilaquiles/8. 20130916-chilaquiles-recipe-1.jpg
#   inflating: mexican_food/train/chilaquiles/80. chilaquiles-verdes-with-fried-egg-1.jpg
#   inflating: mexican_food/train/chilaquiles/81. chilaquiles.jpg
#   inflating: mexican_food/train/chilaquiles/82. chilaquiles-1-600x900.jpg
#   inflating: mexican_food/train/chilaquiles/83. chilaquiles-rojos-paso-a-paso.jpg
#  extracting: mexican_food/train/chilaquiles/84. 478x640_ac.jpg
#   inflating: mexican_food/train/chilaquiles/85. shrimp-grilled-corn-chilaquiles-recipe.jpg
#   inflating: mexican_food/train/chilaquiles/86. salsa-verde-chilaquiles-58a34fb65f9b58819c01381c.jpg
#   inflating: mexican_food/train/chilaquiles/88. fried_eggs_with_a_crispy_99565_16x9.jpg
#   inflating: mexican_food/train/chilaquiles/89. breakfast-chilaquiles-3-2.jpg
#   inflating: mexican_food/train/chilaquiles/9. chilaquiles-eggs-ck-x.jpg
#   inflating: mexican_food/train/chilaquiles/90. chilaquiles-verdes-with-chicken.jpg
#  extracting: mexican_food/train/chilaquiles/91. chilaquiles.jpg
#   inflating: mexican_food/train/chilaquiles/92. chilaquiles6_thumb5.jpg
#   inflating: mexican_food/train/chilaquiles/96. chicken-chilaquiles-recipe-tasteandtellblog.com-2-600x900.jpg
#   inflating: mexican_food/train/chilaquiles/97. how-to-make-chilaquiles-rojos-410x273.jpg
#  extracting: mexican_food/train/chilaquiles/98. guacamole-salsa-chilaquiles-520x300.jpg
#   inflating: mexican_food/train/chilaquiles/99. easy-chilaquiles-fb.jpg
#    creating: mexican_food/train/coctel_camaron/
#  extracting: mexican_food/train/coctel_camaron/1. coctel-de-camaron-12.jpg
#   inflating: mexican_food/train/coctel_camaron/10. img_coctel_de_camarones_11046_600.jpg
#   inflating: mexican_food/train/coctel_camaron/11. 15394a73770c7879059a613876f78de6.jpeg
#  extracting: mexican_food/train/coctel_camaron/12. coctel-de-camaron-13.jpg
#   inflating: mexican_food/train/coctel_camaron/13. img_coctel_de_camarones_en_salsa_12227_600_square.jpg
#   inflating: mexican_food/train/coctel_camaron/14. 121-125.jpg
#   inflating: mexican_food/train/coctel_camaron/15. p1080018.jpg
#   inflating: mexican_food/train/coctel_camaron/16. coctel-de-camarones-62.jpg
#   inflating: mexican_food/train/coctel_camaron/17. coctel-camaron-con-salsa-bruja.jpg
#   inflating: mexican_food/train/coctel_camaron/18. img_coctel_de_camarones_facil_37972_600.jpg
#   inflating: mexican_food/train/coctel_camaron/19. shrimp%252520cocktail%252520camaron1a_thumb%25255b8%25255d.jpg
#   inflating: mexican_food/train/coctel_camaron/2. coctel-de-camaro%cc%81n-4.jpg
#   inflating: mexican_food/train/coctel_camaron/20. 20150728-mexican-shrimp-cocktail-vicky-wasik-4-1500x1125.jpg
#   inflating: mexican_food/train/coctel_camaron/21. dae2964b444306c64f747bfa62b418fa.jpg
#   inflating: mexican_food/train/coctel_camaron/22. th5-640x426-14254.jpg
#   inflating: mexican_food/train/coctel_camaron/23. coctel-de-camaron-1.jpg
#   inflating: mexican_food/train/coctel_camaron/24. coctel-camaron.jpg
#   inflating: mexican_food/train/coctel_camaron/29. so4kpnvqwv1rwwsh9yi3.jpg
#   inflating: mexican_food/train/coctel_camaron/3. p1110835.jpg
#   inflating: mexican_food/train/coctel_camaron/32. coctel-de-camaron-que.jpg
#   inflating: mexican_food/train/coctel_camaron/33. dcr0u2uxcaayhrt.jpg
#   inflating: mexican_food/train/coctel_camaron/34. seafood-400571_1920.jpg
#   inflating: mexican_food/train/coctel_camaron/36. 1505858656760.jpg
#   inflating: mexican_food/train/coctel_camaron/37. coctel-de-camarones.jpg
#   inflating: mexican_food/train/coctel_camaron/38. villas-playa-paraiso.jpg
#   inflating: mexican_food/train/coctel_camaron/4. coctel-de-camaron-7.jpg
#   inflating: mexican_food/train/coctel_camaron/43. coctel-de-camaron-mexican-shrimp-cocktail.jpg
#   inflating: mexican_food/train/coctel_camaron/44. coctel-de-camaron.jpg
#   inflating: mexican_food/train/coctel_camaron/45. original-1.jpeg
#   inflating: mexican_food/train/coctel_camaron/46. coctel+de+camarones.jpg
#   inflating: mexican_food/train/coctel_camaron/48. maxresdefault.jpg
#   inflating: mexican_food/train/coctel_camaron/49. coctail-de-camaron.jpg
#   inflating: mexican_food/train/coctel_camaron/5. coctelcamarones.jpg
#   inflating: mexican_food/train/coctel_camaron/50. coctel-camaron-pint-pq.jpg
#   inflating: mexican_food/train/coctel_camaron/53. coctel-de-camaroness.jpg
#   inflating: mexican_food/train/coctel_camaron/56. coctel-de-camaron_2000x.jpg
#   inflating: mexican_food/train/coctel_camaron/57. image_url=https%3a%2f%2fpespdotcom.files.wordpress.com%2f2018%2f10%2fec81fb69-43a4-4c6c-ade9-be56bbdc8446.jpg%3fw%3d336&w=1000&c=sc&poi=face&q=70.jpg
#   inflating: mexican_food/train/coctel_camaron/58. coctel-de-camaron-673739.jpg
#   inflating: mexican_food/train/coctel_camaron/59. coctel-de-camaron.jpg
#   inflating: mexican_food/train/coctel_camaron/6. 4473632.jpg
#   inflating: mexican_food/train/coctel_camaron/61. 1.jpg
#  extracting: mexican_food/train/coctel_camaron/63. coctel+de+camaron+grande.jpg
#   inflating: mexican_food/train/coctel_camaron/69. los-taquitos-de-puebla.jpg
#   inflating: mexican_food/train/coctel_camaron/7. 7027.jpg
#   inflating: mexican_food/train/coctel_camaron/70. cabi0007-enrique-cocktail-de-camarones-estilo-acapulco-vertical-xl-xxxx80.jpg
#   inflating: mexican_food/train/coctel_camaron/71. coctel-de-camaron.jpg
#   inflating: mexican_food/train/coctel_camaron/72. coctel_de_camaron_mariscos_el_rey.jpg
#   inflating: mexican_food/train/coctel_camaron/73. hqdefault.jpg
#   inflating: mexican_food/train/coctel_camaron/74. 14045865_10154451441777579_8968287262633586659_n.jpg
#   inflating: mexican_food/train/coctel_camaron/75. campechana.jpg
#   inflating: mexican_food/train/coctel_camaron/76. lifestyle-recipes-shrimp-cocktail-20090326-cheflala.jpg
#   inflating: mexican_food/train/coctel_camaron/77. photo.jpg
#   inflating: mexican_food/train/coctel_camaron/79. coctel+de+camarones+don+cuevas.jpg
#   inflating: mexican_food/train/coctel_camaron/8. maxresdefault.jpg
#   inflating: mexican_food/train/coctel_camaron/80. 8-27-shrimpcocktaillandscapeweb-1.jpg
#   inflating: mexican_food/train/coctel_camaron/83. p1050873-3.jpg
#   inflating: mexican_food/train/coctel_camaron/84. mexican-style+shrimp+cocktail+(2)+-+girlichef.com.jpg
#   inflating: mexican_food/train/coctel_camaron/86. camaron_y_pulpo_mariscos_el_rey.jpg
#   inflating: mexican_food/train/coctel_camaron/89. coctel-de-camaron.jpg
#   inflating: mexican_food/train/coctel_camaron/9. coctel-de-camaron-1024x679.jpg
#   inflating: mexican_food/train/coctel_camaron/98. coctel+de+camarones.jpg
#    creating: mexican_food/train/gobernador/
#   inflating: mexican_food/train/gobernador/1. recipe-tacos-gobernador-520x300.jpg
#   inflating: mexican_food/train/gobernador/10. 20180807_165940-3.jpg
#   inflating: mexican_food/train/gobernador/11. maxresdefault.jpg
#   inflating: mexican_food/train/gobernador/12. 1e5e568514137a0aa40614168417f04e.jpg
#   inflating: mexican_food/train/gobernador/13. tacos-de-camaron-750x320.jpg
#   inflating: mexican_food/train/gobernador/14. taco_gobernador_mariscos_el_rey.jpg
#   inflating: mexican_food/train/gobernador/15. 4085031114_68a51f415e_b.jpg
#   inflating: mexican_food/train/gobernador/16. los-arcos-ciudad-juarez.jpg
#   inflating: mexican_food/train/gobernador/17. served6.jpg
#   inflating: mexican_food/train/gobernador/18. taco-gobernador.jpg
#   inflating: mexican_food/train/gobernador/19. o.jpg
#   inflating: mexican_food/train/gobernador/2. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/21. mariscos-ensenada.jpg
#   inflating: mexican_food/train/gobernador/22. photo.jpg
#   inflating: mexican_food/train/gobernador/23. 037.jpg
#   inflating: mexican_food/train/gobernador/24. tacogobernador.jpg
#   inflating: mexican_food/train/gobernador/25. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/26. maxresdefault.jpg
#   inflating: mexican_food/train/gobernador/27. tacos-gobenador.jpg
#   inflating: mexican_food/train/gobernador/28. dsjrpuru8aerfgy.jpg
#   inflating: mexican_food/train/gobernador/29. gobernadortaco.jpg
#   inflating: mexican_food/train/gobernador/3. 277-293.jpg
#   inflating: mexican_food/train/gobernador/31. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/33. 4085033078_9a146b11e4.jpg
#   inflating: mexican_food/train/gobernador/34. tacosgobernador.jpg
#   inflating: mexican_food/train/gobernador/35. tacos%2bgobernador%2b04.jpg
#   inflating: mexican_food/train/gobernador/37. gobernador__t670.jpg
#   inflating: mexican_food/train/gobernador/39. bot.labotana01.kr.jpg
#   inflating: mexican_food/train/gobernador/4. tacosgobernador.jpg
#   inflating: mexican_food/train/gobernador/40. closeup111.jpg
#   inflating: mexican_food/train/gobernador/41. tacos%2bgobernador%2bde%2batun.jpg
#   inflating: mexican_food/train/gobernador/42. taco-gobernador-de-camaron.jpg
#   inflating: mexican_food/train/gobernador/43. tacos-gobernador-web-940x450.jpg
#   inflating: mexican_food/train/gobernador/45. tacos-camaron-cabanna.jpg
#   inflating: mexican_food/train/gobernador/46. cabi0038-enrique-tacos-gobernador-xl-848x477x80xx.jpg
#   inflating: mexican_food/train/gobernador/47. cf007537a09fa965a9085f697d79b22f.jpg
#   inflating: mexican_food/train/gobernador/48. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/49. im-tacosgobernador.jpg
#   inflating: mexican_food/train/gobernador/5. maxresdefault.jpg
#   inflating: mexican_food/train/gobernador/50. 20180807_160012.jpg
#   inflating: mexican_food/train/gobernador/51. 20ci6pq-8y5kblpl6n6s6wejgflat0muhkjjthqf315wk598rvcazamrm6hhqxrzlkkpln9qk6s9wmfsj1uw14t-woghrji0f2yoyjbljpxmlwjxjn5jryqyxovjnwxeszhym-j3.jpg
#   inflating: mexican_food/train/gobernador/53. 20180807_165957-2.jpg
#   inflating: mexican_food/train/gobernador/54. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/55. 55dcb550945bf.image.jpg
#   inflating: mexican_food/train/gobernador/56. 95ca0be50382b1c8f6314d604a7a7cd7.jpg
#   inflating: mexican_food/train/gobernador/57. img-0199_5_152191.jpg
#  extracting: mexican_food/train/gobernador/58. o.jpg
#   inflating: mexican_food/train/gobernador/59. tacos-gobernador-una.jpg
#   inflating: mexican_food/train/gobernador/6. bonifacio-s-cotton-club.jpg
#   inflating: mexican_food/train/gobernador/60. r_148_1475616099.jpg
#   inflating: mexican_food/train/gobernador/61. 20180807_170108.jpg
#   inflating: mexican_food/train/gobernador/62. gobernadortacos.jpg
#   inflating: mexican_food/train/gobernador/63. tacos_gobernador_6231.jpg
#   inflating: mexican_food/train/gobernador/64. 05831af2614f008f2197a69a3c66016b.jpg
#   inflating: mexican_food/train/gobernador/65. tacos-gobernador-de-vegetales.jpg
#   inflating: mexican_food/train/gobernador/66. 2fc5b4b719c853597fd212f0dabe2f54-rimg-w2160-h1080-gmir.jpg
#   inflating: mexican_food/train/gobernador/67. 6607931_taco_gobernador_mariscos_los_corrales.jpg
#   inflating: mexican_food/train/gobernador/69. gobernador1.jpg
#   inflating: mexican_food/train/gobernador/7. maxresdefault.jpg
#   inflating: mexican_food/train/gobernador/70. gobernador-vampiro-rudys-0a44487e.jpeg
#   inflating: mexican_food/train/gobernador/71. 2lgrysm7wswkcmwfhb37v67kcfckidbnq9sqp_9jygpcag1nbk2_8_wtpaqazwd8cdybqyzk9zlnfubk5usuv7k-ltwwijevuengi7ogko5djjueavwveedr-aiiuupsidqvzurb.jpg
#   inflating: mexican_food/train/gobernador/72. 20180807_163614.jpg
#   inflating: mexican_food/train/gobernador/73. cmjges-xaaaa53z.jpg
#   inflating: mexican_food/train/gobernador/74. 2-tacosgobernador.jpg
#   inflating: mexican_food/train/gobernador/75. o.jpg
#   inflating: mexican_food/train/gobernador/76. th5-640x426-6431.jpg
#   inflating: mexican_food/train/gobernador/77. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/78. 1491441213813.jpeg
#   inflating: mexican_food/train/gobernador/8. web_fotoreceta.jpg
#   inflating: mexican_food/train/gobernador/80. negro-durazo-tacos-gobernador_t658.jpg
#   inflating: mexican_food/train/gobernador/81. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/82. o.jpg
#  extracting: mexican_food/train/gobernador/83. 5512365572_9950784515_b.jpg
#   inflating: mexican_food/train/gobernador/84. tacos-gobernador-camarones-foto-gustavo-andrade.jpg
#   inflating: mexican_food/train/gobernador/85. tacos-gobernador-marlin.jpg
#   inflating: mexican_food/train/gobernador/86. im_20150220_vidayestilo01_150229950.jpg
#   inflating: mexican_food/train/gobernador/87. u2264p4652f18849-1412228337-995.jpg
#   inflating: mexican_food/train/gobernador/88. o.jpg
#   inflating: mexican_food/train/gobernador/89. tacos-gobernador-y-marlin.jpg
#   inflating: mexican_food/train/gobernador/9. portada-delicias-del-mar-tacos-gobernador-foto-kirk-k.jpg
#   inflating: mexican_food/train/gobernador/90. f072496d-b2f9-41b3-9ec3-5e1b47961168.jpg
#   inflating: mexican_food/train/gobernador/91. 1382539456217.jpeg
#   inflating: mexican_food/train/gobernador/92. 8hdi4lohxkkhx0hs1zis28iqazkcvtw78yvo2liu2gleavqv1d1ug-lr5y95bjxj0txto-verm26xfjcpa-uwnz4mf5i_iligdvm-o_wbq2no0qs_jha1k64vzeuucg6spy8qcyw.jpg
#   inflating: mexican_food/train/gobernador/93. tacos-gobernador-s1c2t4.jpg
#   inflating: mexican_food/train/gobernador/94. 9769273_orig.jpg
#   inflating: mexican_food/train/gobernador/95. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/96. 84471a95e5223e31c0cd2ab5fa586d0b.jpg
#   inflating: mexican_food/train/gobernador/97. tacos-gobernador.jpg
#   inflating: mexican_food/train/gobernador/98. tacos-el-rorro-fish-grilled-shrimp-and-gobernador-tacos_t670.jpg
#    creating: mexican_food/train/pozole/
#   inflating: mexican_food/train/pozole/1. pozole-5-1024x681-1.jpg
#  extracting: mexican_food/train/pozole/10. 53423e00-6d96-4bdf-831e-4708131726ec--pozole.jpg
#  extracting: mexican_food/train/pozole/11. 64f37375-c2a3-4d3e-8fb7-141b4bdb37ef.jpg
#  extracting: mexican_food/train/pozole/12. pozole-rojo-3-square-1.jpg
#   inflating: mexican_food/train/pozole/14. redpozolerecipe6a.jpg
#   inflating: mexican_food/train/pozole/15. jackfruit-pozole-8.jpg
#   inflating: mexican_food/train/pozole/17. cooked-pozole.jpg
#   inflating: mexican_food/train/pozole/18. pozole-sl-x.jpg
#   inflating: mexican_food/train/pozole/2. posole-rojo-vertical-b2-1600.jpg
#   inflating: mexican_food/train/pozole/20. 2870c99a-a9a6-4b3e-8d16-051d9c664c66.jpg
#   inflating: mexican_food/train/pozole/21. pozole-de-garbanzo_1500.jpg
#   inflating: mexican_food/train/pozole/24. 9902.jpg
#   inflating: mexican_food/train/pozole/25. pork-and-chorizo-pozole-xl-wnbook2014.jpg
#   inflating: mexican_food/train/pozole/27. red-pozole-recipe-fp-400x400-c.jpg
#   inflating: mexican_food/train/pozole/29. c30b6d261275ffb9c0cdbc7622e5c517.jpg
#   inflating: mexican_food/train/pozole/3. 04kitch_span-articlelarge.jpg
#   inflating: mexican_food/train/pozole/31. pozolerojo-1.jpg
#   inflating: mexican_food/train/pozole/33. pozole-rojo-latinofoodie-vert.jpg
#   inflating: mexican_food/train/pozole/37. pozole-10.jpg
#   inflating: mexican_food/train/pozole/38. leftover-turkey-pozole-rojo-notext.jpg
#   inflating: mexican_food/train/pozole/39. pozole-recipe-ceja-vineyards-4.jpg
#   inflating: mexican_food/train/pozole/4. 1522172425417.jpeg
#   inflating: mexican_food/train/pozole/40. pozole1_.jpg
#  extracting: mexican_food/train/pozole/41. maxresdefault.jpg
#   inflating: mexican_food/train/pozole/43. maxresdefault.jpg
#   inflating: mexican_food/train/pozole/46. 043.jpg
#   inflating: mexican_food/train/pozole/49. red-chile-chicken-posole-3-2.jpg
#   inflating: mexican_food/train/pozole/53. ed7e306f85179f0297b39a7c20e4dd9b.jpg
#  extracting: mexican_food/train/pozole/54. pozole-rojo.jpg
#  extracting: mexican_food/train/pozole/55. green-pozole-with-chicken.jpg
#  extracting: mexican_food/train/pozole/56. pozole-rojo-2.jpg
#   inflating: mexican_food/train/pozole/57. pozole-rojo-tosott.jpg
#   inflating: mexican_food/train/pozole/58. red_chili_and_pork_posole_large.jpg
#   inflating: mexican_food/train/pozole/6. image_url=https%3a%2f%2fcdn-image.foodandwine.com%2fsites%2fdefault%2ffiles%2fstyles%2fmedium_2x%2fpublic%2f1530117382%2fposole-rojo-ft-recipe0818.jpg%3fitok%3dwhzehl4l&w=1000&c=sc&poi=face&q=70.jpg
#  extracting: mexican_food/train/pozole/60. th5-640x426-28933.jpg
#   inflating: mexican_food/train/pozole/63. th5-640x426-24175.jpg
#   inflating: mexican_food/train/pozole/67. 051120059-01-pozole-rojo-recipe-main.jpg
#  extracting: mexican_food/train/pozole/68. a8848088-1c59-4879-a692-e728b7062e62.jpg
#   inflating: mexican_food/train/pozole/7. sobu9ljr3qh8ul37iavw_pork-pozole-7704.jpg
#  extracting: mexican_food/train/pozole/70. pozole-rojo.jpg
#   inflating: mexican_food/train/pozole/73. pozole_rojo_alfresco.jpg
#   inflating: mexican_food/train/pozole/77. pozole+2_edited-1+copy.jpg
#   inflating: mexican_food/train/pozole/79. posole-mexican-soup-ls.jpg
#   inflating: mexican_food/train/pozole/8. pozole-rojo.jpg
#   inflating: mexican_food/train/pozole/80. 501025.jpg
#  extracting: mexican_food/train/pozole/81. redpozole1.jpg
#   inflating: mexican_food/train/pozole/83. 97538b5f-5548-4c9b-b699-e548a9bdd231--pozole_013b.jpg
#   inflating: mexican_food/train/pozole/88. beef-pozole-102383692.jpg
#   inflating: mexican_food/train/pozole/89. large_cropped_k0ezq97jtuimljdy3suq_chipotle_chicken_pozole_with_crispy_quesadillas___0035___main.jpg
#   inflating: mexican_food/train/pozole/93. red-chile-sauce-and-slow-cooker-pozole-rojo.jpg
#   inflating: mexican_food/train/pozole/94. pozole_v2.jpg
#   inflating: mexican_food/train/pozole/96. pozole-feature.jpg
#   inflating: mexican_food/train/pozole/98. sd-pozole-articlelarge-v2.jpg
#    creating: mexican_food/train/zarandeado/
#   inflating: mexican_food/train/zarandeado/1. pescadozarandeado3.jpg
#   inflating: mexican_food/train/zarandeado/100. taco-gusanos2.jpg
#   inflating: mexican_food/train/zarandeado/11. 3845959=s1280=h960.jpg
#  extracting: mexican_food/train/zarandeado/12. maxresdefault.jpg
#  extracting: mexican_food/train/zarandeado/13. pescado_zarandeado1.jpg
#   inflating: mexican_food/train/zarandeado/15. pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/16. pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/17. pescado-zarandeado-nayarit-2.jpg
#   inflating: mexican_food/train/zarandeado/19. pescado-zarandeado-estilo-nayarit-620x400.jpg
#   inflating: mexican_food/train/zarandeado/2. pescado-zarandeado-1024x635.jpg
#   inflating: mexican_food/train/zarandeado/21. o.jpg
#   inflating: mexican_food/train/zarandeado/22. pescado-zarandeado-very.jpg
#   inflating: mexican_food/train/zarandeado/23. pescado-zarandeado-580x580.jpg
#   inflating: mexican_food/train/zarandeado/24. 7c527dcec3adfc20fcda891ab4ef5b7d.jpg
#   inflating: mexican_food/train/zarandeado/25. receta-pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/26. delicious-pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/27. pescado%2bzarandeado%2bestilo%2bsinaloa.jpg
#   inflating: mexican_food/train/zarandeado/28. r_1183_1475613663.jpg
#  extracting: mexican_food/train/zarandeado/29. pescado-zarandeado-web-1-940x450.jpg
#   inflating: mexican_food/train/zarandeado/30. mariscos-tino-s-malecon.jpg
#   inflating: mexican_food/train/zarandeado/31. 25-pescado_sarandeado-1.jpg
#   inflating: mexican_food/train/zarandeado/32. snook.jpg
#   inflating: mexican_food/train/zarandeado/34. pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/35. hqdefault.jpg
#   inflating: mexican_food/train/zarandeado/36. zoom-9983468e85a8e69a2ffeea2af85cafa1-920-518.jpg
#   inflating: mexican_food/train/zarandeado/38. ecd66676-811c-6377-b9d8-ff0000673b69-604x840-default_jpeg_2.jpg
#   inflating: mexican_food/train/zarandeado/39. mariscos-tinos-punta.jpg
#   inflating: mexican_food/train/zarandeado/4. _o8a8650.jpg
#   inflating: mexican_food/train/zarandeado/40. fishdish-3.jpg
#   inflating: mexican_food/train/zarandeado/41. 4a4e5be42c736eeb9130052a6b9d2531.jpg
#   inflating: mexican_food/train/zarandeado/48. pescado-zarandeado-grilled-fish-puerto-vallarta-jalisco-mexico-md8dym.jpg
#   inflating: mexican_food/train/zarandeado/49. pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/50. pescado-zarandeado-001-larousse-cocina_0.jpg
#   inflating: mexican_food/train/zarandeado/51. receta-de-pescado-zarandeado-o-s.jpg
#   inflating: mexican_food/train/zarandeado/52. pescadozarandeado_semanasanta.jpg
#   inflating: mexican_food/train/zarandeado/54. u3p11799f45371-1525228595-fa7.jpg
#  extracting: mexican_food/train/zarandeado/57. pescadozarandeadosml-1024x846.jpg
#   inflating: mexican_food/train/zarandeado/58. pesca.jpg
#   inflating: mexican_food/train/zarandeado/59. pz_mpe.jpg
#   inflating: mexican_food/train/zarandeado/6. img_pescado_zarandeado_32222_600.jpg
#   inflating: mexican_food/train/zarandeado/60. 33554711522_b8faf8a3be_b.jpg
#   inflating: mexican_food/train/zarandeado/62. pescado-zarandeado-receta-secreta.jpg
#   inflating: mexican_food/train/zarandeado/63. paolo-gamma.jpg
#   inflating: mexican_food/train/zarandeado/64. pescado-zarandeado-mazatlan.jpg
#   inflating: mexican_food/train/zarandeado/65. pescado-zarandeado-580x237.jpg
#  extracting: mexican_food/train/zarandeado/67. maxresdefault.jpg
#   inflating: mexican_food/train/zarandeado/68. pescado-zarandeado-para.jpg
#   inflating: mexican_food/train/zarandeado/69. pescado-zarandeado-1.jpg
#   inflating: mexican_food/train/zarandeado/70. pescado_zarandeado_2.jpg
#   inflating: mexican_food/train/zarandeado/71. zarandeado-620x422.jpg
#   inflating: mexican_food/train/zarandeado/72. maxresdefault.jpg
#   inflating: mexican_food/train/zarandeado/73. pescado%20zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/74. pescado-zarandeado-mex-co-1080x658.jpg
#   inflating: mexican_food/train/zarandeado/75. pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/76. maxresdefault.jpg
#   inflating: mexican_food/train/zarandeado/77. pescado-zarandeado-nayarit-4.jpg
#   inflating: mexican_food/train/zarandeado/78. image_url=https%3a%2f%2fcdn-image.myrecipes.com%2fsites%2fdefault%2ffiles%2fstyles%2fmedium_2x%2fpublic%2fimage%2frecipes%2fck%2f14%2f05%2fpescado-sarandeado-ck-x.jpg%3fitok%3dz0nzz6a0&w=1000&c=sc&poi=face&q=70.jpg
#  extracting: mexican_food/train/zarandeado/79. coni_seafood_crystal_coser.0.jpg
#   inflating: mexican_food/train/zarandeado/8. image_url=https%3a%2f%2fpespdotcom.files.wordpress.com%2f2018%2f10%2f440966d7-122c-49ec-9f5c-99d83577e8ff.jpg%3fw%3d320&w=1000&c=sc&poi=face&q=70.jpg
#   inflating: mexican_food/train/zarandeado/80. pescado-zarandeado-mazatlan.jpg
#   inflating: mexican_food/train/zarandeado/81. pescado_zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/82. mariscos-mazatlan.jpg
#   inflating: mexican_food/train/zarandeado/83. image_url=https%3a%2f%2fpespdotcom.files.wordpress.com%2f2018%2f10%2fef8c2244-8954-4e19-87f8-09bcaed196db.jpg%3fw%3d1280&w=1000&c=sc&poi=face&q=70.jpg
#   inflating: mexican_food/train/zarandeado/84. sarandeado1.jpg
#   inflating: mexican_food/train/zarandeado/85. comida-mazatlan-pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/86. dsc_0084.jpg
#   inflating: mexican_food/train/zarandeado/87. pescado_talla_pinterest.jpg
#   inflating: mexican_food/train/zarandeado/88. hqdefault.jpg
#   inflating: mexican_food/train/zarandeado/89. pescado-zarandeado.jpg
#   inflating: mexican_food/train/zarandeado/9. pescado-zarandeado-zanaya.jpg
#   inflating: mexican_food/train/zarandeado/90. saran21.jpg
#   inflating: mexican_food/train/zarandeado/91. 596426819806_01141001_596426819806_large.jpg
#   inflating: mexican_food/train/zarandeado/92. pescado-zarandeado-mazatlan.jpg
#  extracting: mexican_food/train/zarandeado/93. pescado-sarandeado-puerto-vallarta-001.jpg
#   inflating: mexican_food/train/zarandeado/94. maxresdefault.jpg
#   inflating: mexican_food/train/zarandeado/95. zarandeado2.jpg
#   inflating: mexican_food/train/zarandeado/96. ctii39x.jpg
#   inflating: mexican_food/train/zarandeado/97. hqdefault.jpg
#   inflating: mexican_food/train/zarandeado/98. zarandeado3.jpg
#   inflating: mexican_food/train/zarandeado/99. pescado-zarandeado.jpg
#    creating: mexican_food/valid/
#    creating: mexican_food/valid/aguachile/
#   inflating: mexican_food/valid/aguachile/9696-481.jpg
#   inflating: mexican_food/valid/aguachile/aguachi.jpg
#   inflating: mexican_food/valid/aguachile/aguachile.jpg
#   inflating: mexican_food/valid/aguachile/aguachilecama.jpg
#   inflating: mexican_food/valid/aguachile/agua_n.jpg
#   inflating: mexican_food/valid/aguachile/camaron aguachile2.jpg
#   inflating: mexican_food/valid/aguachile/hqdefault.jpg
#   inflating: mexican_food/valid/aguachile/images.jpg
#   inflating: mexican_food/valid/aguachile/receta-facil-de-camaron-en-limon.jpg
#    creating: mexican_food/valid/callos_hacha/
#   inflating: mexican_food/valid/callos_hacha/callos-de-hacha-mazatlan.jpg
#   inflating: mexican_food/valid/callos_hacha/callos.jpg
#  extracting: mexican_food/valid/callos_hacha/callos1.jpg
#   inflating: mexican_food/valid/callos_hacha/images.jpg
#   inflating: mexican_food/valid/callos_hacha/maxresdefault.jpg
#    creating: mexican_food/valid/ceviche_camaron/
#   inflating: mexican_food/valid/ceviche_camaron/11287676524_a989e5e86e.jpg
#   inflating: mexican_food/valid/ceviche_camaron/18161529_234258497071427_3816056817335664640_n.jpg
#   inflating: mexican_food/valid/ceviche_camaron/42323488_172517350306546_4470149328956589513_n.jpg
#   inflating: mexican_food/valid/ceviche_camaron/Ceviche-de-pescado-estilo-Santa-Marбa-del-Oro.jpg
#   inflating: mexican_food/valid/ceviche_camaron/cevichecamaron.jpg
#   inflating: mexican_food/valid/ceviche_camaron/ceviche_camaron.jpg
#    creating: mexican_food/valid/ceviche_sierra/
#   inflating: mexican_food/valid/ceviche_sierra/30079318_420549371739518_5902674301940662272_n.jpg
#   inflating: mexican_food/valid/ceviche_sierra/359-378.jpg
#  extracting: mexican_food/valid/ceviche_sierra/Ceviche-de-sierra-mazatleco.jpg
#   inflating: mexican_food/valid/ceviche_sierra/ceviche-sierra-mazatlan.jpg
#   inflating: mexican_food/valid/ceviche_sierra/ceviche-sierra.jpg
#   inflating: mexican_food/valid/ceviche_sierra/FSZSM8RIK7C7ZLK.RECTANGLE1.jpg
#   inflating: mexican_food/valid/ceviche_sierra/index.jpg
#    creating: mexican_food/valid/chilaquiles/
#   inflating: mexican_food/valid/chilaquiles/3910356815_a83b511b0d_o.jpg
#   inflating: mexican_food/valid/chilaquiles/chila.jpg
#   inflating: mexican_food/valid/chilaquiles/Chilaquiles.jpg
#   inflating: mexican_food/valid/chilaquiles/DE-CHILAQUILES-ROJOS-SUIZOS-CON-BISTEC-DE-CERDO.jpg
#   inflating: mexican_food/valid/chilaquiles/excelente-los-chilaquiles.jpg
#  extracting: mexican_food/valid/chilaquiles/maxresdefault.jpg
#    creating: mexican_food/valid/coctel_camaron/
#   inflating: mexican_food/valid/coctel_camaron/115102fdf53e8d0b698f21f58daad542.jpeg
#   inflating: mexican_food/valid/coctel_camaron/4064627.jpg
#   inflating: mexican_food/valid/coctel_camaron/699390_2d9fb14827594ded97c9e807858ef45f~mv2.jpg
#   inflating: mexican_food/valid/coctel_camaron/COCTEL DE CAMARONES2.jpg
#   inflating: mexican_food/valid/coctel_camaron/EXPS_96151_TH133086C08_01_12bC_RMS.jpg
#   inflating: mexican_food/valid/coctel_camaron/mexican-shrimp-cocktail-horiz-a-1200.jpg
#   inflating: mexican_food/valid/coctel_camaron/Mexican_Seafood_Cocktail_9.jpg
#    creating: mexican_food/valid/gobernador/
#   inflating: mexican_food/valid/gobernador/78C.jpg
#   inflating: mexican_food/valid/gobernador/images.jpg
#   inflating: mexican_food/valid/gobernador/images1.jpg
#   inflating: mexican_food/valid/gobernador/o.jpg
#   inflating: mexican_food/valid/gobernador/tacos-gobernador.jpg
#    creating: mexican_food/valid/pozole/
#   inflating: mexican_food/valid/pozole/27.-pozole-rojo-estilo-guerrero-300x225.jpg
#   inflating: mexican_food/valid/pozole/Pozole Rojo estilo Sinaloa.jpg
#   inflating: mexican_food/valid/pozole/pozole-estilo-nayarit.jpg
#   inflating: mexican_food/valid/pozole/pozole.jpg
#  extracting: mexican_food/valid/pozole/Pozole1.jpg
#   inflating: mexican_food/valid/pozole/PozoleRojo.jpeg
#  extracting: mexican_food/valid/pozole/r_4087_1475600618.jpg
#    creating: mexican_food/valid/zarandeado/
#   inflating: mexican_food/valid/zarandeado/1501656_img_8794.jpg
#   inflating: mexican_food/valid/zarandeado/zaran.jpg
#   inflating: mexican_food/valid/zarandeado/zarandeado.jpg
#   inflating: mexican_food/valid/zarandeado/Zarandeado2.JPG

# %%
data_dir = '/mexican_food'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
nThreads = 4
batch_size = 32
use_gpu = torch.cuda.is_available()

# %% [markdown]
# # Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the mexican food classes.

# %%
import json

with open('cate.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
# Define your transforms for the training and validation sets
# Data augmentation and normalization for training
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(30),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# Load the datasets with ImageFolder

data_dir = 'mexican_food'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'valid']}

# Using the image datasets and the trainforms, define the dataloaders
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'valid']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'valid']}

class_names = image_datasets['train'].classes

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features. I will use Resnet-152.

# %%
# Build and train your network

# 1. Load resnet-152 pre-trained network
model = models.resnet152(pretrained=True)
# Freeze parameters so we don't backprop through them

for param in model.parameters():
    param.requires_grad = False

print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.torch/models/resnet152-b121ed2d.pth
# 100%|██████████| 241530880/241530880 [00:19<00:00, 12480860.81it/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# 2. Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout

# Our input_size matches the in_features of pretrained model


from collections import OrderedDict


# Creating the classifier ordered dictionary first

classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(2048, 512)),
                          ('relu', nn.ReLU()),
                          #('dropout1', nn.Dropout(p=0.3)),
                          ('fc2', nn.Linear(512, 9)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))



# Replacing the pretrained model classifier with our classifier
model.fc = classifier

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=20):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(1, num_epochs+1):
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs, labels = inputs.to(device), labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward
                # Track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # Deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best valid accuracy: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
warnings.filterwarnings("ignore", "(Possibly )?corrupt EXIF data", UserWarning)

# Train a model with a pre-trained network
num_epochs = 15
if use_gpu:
    print ("Using GPU: "+ str(use_gpu))
    model = model.cuda()

# NLLLoss because our output is LogSoftmax
criterion = nn.NLLLoss()

# Adam optimizer with a learning rate
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)
# Optimizer = optim.SGD(model.fc.parameters(), lr = .1, momentum=0.9)
# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)


model_ft = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=15)
# Out:
# Using GPU: True
# Epoch 1/15
# ----------
# train Loss: 0.8190 Acc: 0.7118
# valid Loss: 0.6022 Acc: 0.8214
#
# Epoch 2/15
# ----------
# train Loss: 0.7082 Acc: 0.7569
# valid Loss: 0.5290 Acc: 0.8036
#
# Epoch 3/15
# ----------
# train Loss: 0.7533 Acc: 0.7483
# valid Loss: 0.6262 Acc: 0.7679
#
# Epoch 4/15
# ----------
# train Loss: 0.7106 Acc: 0.7552
# valid Loss: 0.5518 Acc: 0.7679
#
# Epoch 5/15
# ----------
# train Loss: 0.6441 Acc: 0.7760
# valid Loss: 0.5902 Acc: 0.8036
#
# Epoch 6/15
# ----------
# train Loss: 0.6474 Acc: 0.7951
# valid Loss: 0.3792 Acc: 0.9107
#
# Epoch 7/15
# ----------
# train Loss: 0.4929 Acc: 0.8316
# valid Loss: 0.3631 Acc: 0.8929
#
# Epoch 8/15
# ----------
# train Loss: 0.4539 Acc: 0.8507
# valid Loss: 0.3614 Acc: 0.9107
#
# Epoch 9/15
# ----------
# train Loss: 0.4957 Acc: 0.8368
# valid Loss: 0.3640 Acc: 0.8929
#
# Epoch 10/15
# ----------
# train Loss: 0.4566 Acc: 0.8698
# valid Loss: 0.3513 Acc: 0.8929
#
# Epoch 11/15
# ----------
# train Loss: 0.4647 Acc: 0.8385
# valid Loss: 0.3547 Acc: 0.9107
#
# Epoch 12/15
# ----------
# train Loss: 0.4743 Acc: 0.8594
# valid Loss: 0.3569 Acc: 0.8929
#
# Epoch 13/15
# ----------
# train Loss: 0.4409 Acc: 0.8663
# valid Loss: 0.3596 Acc: 0.9107
#
# Epoch 14/15
# ----------
# train Loss: 0.4655 Acc: 0.8490
# valid Loss: 0.3496 Acc: 0.9107
#
# Epoch 15/15
# ----------
# train Loss: 0.4566 Acc: 0.8455
# valid Loss: 0.3407 Acc: 0.9107
#
# Training complete in 30m 29s
# Best valid accuracy: 0.910714

# %%
# Do validation on the test set
def test(model, dataloaders, device):
  model.eval()
  accuracy = 0
  
  model.to(device)
    
  for images, labels in dataloaders['valid']:
    images = Variable(images)
    labels = Variable(labels)
    images, labels = images.to(device), labels.to(device)
      
    output = model.forward(images)
    ps = torch.exp(output)
    equality = (labels.data == ps.max(1)[1])
    accuracy += equality.type_as(torch.FloatTensor()).mean()
      
    print("Testing Accuracy: {:.3f}".format(accuracy/len(dataloaders['valid'])))

# %%
test(model, dataloaders, device)
# Out:
# Testing Accuracy: 0.453
# Testing Accuracy: 0.911

# %% [markdown]
# # Save the checkpoint
#
# Now that the network is trained,  we will save the model so we can load it later for making predictions. We will save the mapping of classes to indices which we get from one of the image datasets: `image_datasets['train'].class_to_idx`. We will attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that we'll want to completely rebuild the model later so we can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# Save the checkpoint 

model.class_to_idx = dataloaders['train'].dataset.class_to_idx
model.epochs = num_epochs
checkpoint = {'input_size': [3, 224, 224],
                 'batch_size': dataloaders['train'].batch_size,
                  'output_size': 9,
                  'state_dict': model.state_dict(),
                  'data_transforms': data_transforms,
                  'optimizer_dict':optimizer.state_dict(),
                  'class_to_idx': model.class_to_idx,
                  'epoch': model.epochs}
torch.save(checkpoint, 'mexicanfood91_checkpoint.pth')

# %% [markdown]
# # Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Write a function that loads a checkpoint and rebuilds the model

def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = models.resnet152()
    
    # Our input_size matches the in_features of pretrained model
    input_size = 2048
    output_size = 9
    
    classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(2048, 512)),
                          ('relu', nn.ReLU()),
                          #('dropout1', nn.Dropout(p=0.2)),
                          ('fc2', nn.Linear(512, 9)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))

    # Replacing the pretrained model classifier with our classifier
    model.fc = classifier
    
    
    model.load_state_dict(checkpoint['state_dict'])
    
    return model, checkpoint['class_to_idx']

# Get index to class mapping
loaded_model, class_to_idx = load_checkpoint('mexicanfood91_checkpoint.pth')
idx_to_class = { v : k for k,v in class_to_idx.items()}

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the mexican food dish in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # Process a PIL image for use in a PyTorch model

    size = 256, 256
    image.thumbnail(size, Image.ANTIALIAS)
    image = image.crop((128 - 112, 128 - 112, 128 + 112, 128 + 112))
    npImage = np.array(image)
    npImage = npImage/255.
        
    imgA = npImage[:,:,0]
    imgB = npImage[:,:,1]
    imgC = npImage[:,:,2]
    
    imgA = (imgA - 0.485)/(0.229) 
    imgB = (imgB - 0.456)/(0.224)
    imgC = (imgC - 0.406)/(0.225)
        
    npImage[:,:,0] = imgA
    npImage[:,:,1] = imgB
    npImage[:,:,2] = imgC
    
    npImage = np.transpose(npImage, (2,0,1))
    
    return npImage

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# # Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # Implement the code to predict the class from an image file
    
    image = torch.FloatTensor([process_image(Image.open(image_path))])
    model.eval()
    output = model.forward(Variable(image))
    pobabilities = torch.exp(output).data.numpy()[0]
    

    top_idx = np.argsort(pobabilities)[-topk:][::-1] 
    top_class = [idx_to_class[x] for x in top_idx]
    top_probability = pobabilities[top_idx]

    return top_probability, top_class

# %%
print (predict('mexican_food/valid/aguachile/aguachi.jpg', loaded_model))
# Out:
# (array([0.8541554 , 0.05768677, 0.0361561 , 0.01597102, 0.01201749],
#       dtype=float32), ['aguachile', 'ceviche_camaron', 'chilaquiles', 'gobernador', 'callos_hacha'])

# %% [markdown]
# # Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the validation accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:

# %%
# Display an image along with the top 5 classes
def view_classify(img, probabilities, classes, mapper):
    ''' Function for viewing an image and it's predicted classes.
    '''
    img_filename = img.split('/')[-2]
    img = Image.open(img)

    fig, (ax1, ax2) = plt.subplots(figsize=(6,10), ncols=1, nrows=2)
    food_name = mapper[img_filename]
    
    ax1.set_title(food_name)
    ax1.imshow(img)
    ax1.axis('off')
    
    y_pos = np.arange(len(probabilities))
    ax2.barh(y_pos, probabilities)
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels([mapper[x] for x in classes])
    ax2.invert_yaxis()

# %%
img = 'mexican_food/valid/ceviche_camaron/ceviche_camaron.jpg'
p, c = predict(img, loaded_model)
view_classify(img, p, c, cat_to_name)

# %%
img = 'mexican_food/valid/ceviche_sierra/ceviche-sierra.jpg'
p, c = predict(img, loaded_model)
view_classify(img, p, c, cat_to_name)

# %%
img = 'mexican_food/valid/gobernador/tacos-gobernador.jpg'
p, c = predict(img, loaded_model)
view_classify(img, p, c, cat_to_name)

# %%
img = 'mexican_food/valid/callos_hacha/images.jpg'
p, c = predict(img, loaded_model)
view_classify(img, p, c, cat_to_name)

# %%
img = 'mexican_food/valid/coctel_camaron/4064627.jpg'
p, c = predict(img, loaded_model)
view_classify(img, p, c, cat_to_name)

# %%
img = 'mexican_food/valid/chilaquiles/Chilaquiles.jpg'
p, c = predict(img, loaded_model)
view_classify(img, p, c, cat_to_name)

# %% [markdown]
# # CONCLUSIONS
#
# I'm happy with the results, even when the dataset is small. You can use a bigger dataset and add more classes to the project. The more the pics, better results. Experiment with different pretrained models and change hyperparameters to get different results!
